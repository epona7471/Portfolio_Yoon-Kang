# %%
# Mount to your personal google drive for saving

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q https://github.com/tugstugi/dl-colab-notebooks/archive/colab_utils.zip
# !pip install noisereduce

# download dataset for script reading
# !pip install git+https://github.com/huggingface/datasets
# Out:
#      - 3.0 kB 8.3 MB/s
#   Building wheel for Deep-Learning-Colab-Notebook-Utils (setup.py) ... done
# Collecting noisereduce
#   Downloading noisereduce-2.0.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from noisereduce) (4.62.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from noisereduce) (1.0.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from noisereduce) (1.4.1)
# Requirement already satisfied: librosa in /usr/local/lib/python3.7/dist-packages (from noisereduce) (0.8.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from noisereduce) (3.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from noisereduce) (1.19.5)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.7/dist-packages (from librosa->noisereduce) (1.5.1)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from librosa->noisereduce) (0.2.2)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from librosa->noisereduce) (0.22.2.post1)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa->noisereduce) (2.1.9)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa->noisereduce) (4.4.2)
# Requirement already satisfied: numba>=0.43.0 in /usr/local/lib/python3.7/dist-packages (from librosa->noisereduce) (0.51.2)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.7/dist-packages (from librosa->noisereduce) (0.10.3.post1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from librosa->noisereduce) (21.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa->noisereduce) (57.4.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa->noisereduce) (0.34.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->librosa->noisereduce) (2.4.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa->noisereduce) (2.23.0)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa->noisereduce) (1.4.4)
# Requirement already satisfied: six>=1.3 in /usr/local/lib/python3.7/dist-packages (from resampy>=0.2.2->librosa->noisereduce) (1.15.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile>=0.10.2->librosa->noisereduce) (1.14.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa->noisereduce) (2.20)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->noisereduce) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->noisereduce) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->noisereduce) (0.10.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->pooch>=1.0->librosa->noisereduce) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->pooch>=1.0->librosa->noisereduce) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->pooch>=1.0->librosa->noisereduce) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->pooch>=1.0->librosa->noisereduce) (2021.5.30)
# Installing collected packages: noisereduce
# Successfully installed noisereduce-2.0.0
# Collecting git+https://github.com/huggingface/datasets
#   Cloning https://github.com/huggingface/datasets to /tmp/pip-req-build-2flqjr1r
#   Running command git clone -q https://github.com/huggingface/datasets /tmp/pip-req-build-2flqjr1r
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets==1.12.2.dev0) (1.19.5)
# Requirement already satisfied: pyarrow!=4.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets==1.12.2.dev0) (3.0.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets==1.12.2.dev0) (0.3.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets==1.12.2.dev0) (1.1.5)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets==1.12.2.dev0) (2.23.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets==1.12.2.dev0) (4.62.2)
# Collecting xxhash
#   Downloading xxhash-2.0.2-cp37-cp37m-manylinux2010_x86_64.whl (243 kB)
#      |████████████████████████████████| 243 kB 4.3 MB/s
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets==1.12.2.dev0) (0.70.12.2)
# Collecting fsspec[http]>=2021.05.0
#   Downloading fsspec-2021.8.1-py3-none-any.whl (119 kB)
#      |████████████████████████████████| 119 kB 47.1 MB/s
# Collecting aiohttp
#   Downloading aiohttp-3.7.4.post0-cp37-cp37m-manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 59.5 MB/s
# Collecting huggingface_hub<0.1.0,>=0.0.14
#   Downloading huggingface_hub-0.0.17-py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 1.3 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets==1.12.2.dev0) (21.0)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.7/dist-packages (from datasets==1.12.2.dev0) (4.8.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface_hub<0.1.0,>=0.0.14->datasets==1.12.2.dev0) (3.0.12)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from huggingface_hub<0.1.0,>=0.0.14->datasets==1.12.2.dev0) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets==1.12.2.dev0) (2.4.7)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.12.2.dev0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.12.2.dev0) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.12.2.dev0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.12.2.dev0) (2.10)
# Collecting async-timeout<4.0,>=3.0
#   Downloading async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.6.3-cp37-cp37m-manylinux2014_x86_64.whl (294 kB)
#      |████████████████████████████████| 294 kB 56.0 MB/s
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==1.12.2.dev0) (21.2.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.1.0-cp37-cp37m-manylinux2014_x86_64.whl (142 kB)
#      |████████████████████████████████| 142 kB 57.1 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib_metadata->datasets==1.12.2.dev0) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets==1.12.2.dev0) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets==1.12.2.dev0) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets==1.12.2.dev0) (1.15.0)
# Building wheels for collected packages: datasets
#   Building wheel for datasets (setup.py) ... done
#   Created wheel for datasets: filename=datasets-1.12.2.dev0-py3-none-any.whl size=274402 sha256=1f76e17c2ee8de5579587232cc5ad7308b4b6413843bea49e5bd6c64c1030317
#   Stored in directory: /tmp/pip-ephem-wheel-cache-uct5xhbj/wheels/cb/6a/f6/1b735389402c6a7cfd6af75fae91ac8ac34d900c197df34b67
# Successfully built datasets
# Installing collected packages: multidict, yarl, async-timeout, fsspec, aiohttp, xxhash, huggingface-hub, datasets
# Successfully installed aiohttp-3.7.4.post0 async-timeout-3.0.1 datasets-1.12.2.dev0 fsspec-2021.8.1 huggingface-hub-0.0.17 multidict-5.1.0 xxhash-2.0.2 yarl-1.6.3

# %%
from IPython.display import display, Audio, clear_output
import ipywidgets as widgets
from dl_colab_notebooks.audio import record_audio, upload_audio
from scipy.io.wavfile import write, read
import time
from google.colab import output

# %%
# Download script

from datasets import load_dataset, load_metric
import pandas as pd

timit = load_dataset("timit_asr")
timit = timit.remove_columns(["phonetic_detail", "word_detail", "dialect_region", "id", "sentence_type", "speaker_id",'file'])
df = pd.DataFrame(timit['train'])

# %%
print(df['text'][:10])
# Out:
# 0              Would such an act of refusal be useful?
# 1         Don't ask me to carry an oily rag like that.
# 2    Butterscotch fudge goes well with vanilla ice ...
# 3    She had your dark suit in greasy wash water al...
# 4                                      I honor my mom.
# 5            Ambidextrous pickpockets accomplish more.
# 6    Pledge to participate in Nevada's aquatic comp...
# 7                      We'll talk over at your office.
# 8    Soil redeposition is evaluated by washing clea...
# 9    The groundhog clearly saw his shadow, but stay...
# Name: text, dtype: object

# %% [markdown]
# There is overlapped scripts so save only unique scripts

# %%
print(len(df['text']))

# drop duplicated values 
df = df.drop_duplicates()

print('Total length of script data :', len(df['text']))
# Out:
# 1736
# Total length of script data : 1736

# %% [markdown]
# You should pick how many sentences you want to record. The more the better quality is. It normally takes 30 minutes to record 100 sentences. Please choose your size of the dataset.

# %% [markdown]
# How to record a speech data.
# 0. Set the value of variable 'count' which sets the size of the speech dataset
# 1. Before recording every sentence, there is 3 second stanby time. While then, please check the following script and prepare for recording.
# 2. After 3 sec, you can see the new message 'Starting recording for (6) seconds...', which mean recording has started.
# 3. Read the popped sentence loudly and clearly. If recording time is too short, you can change the 'record_seconds' value longer.

# %%
#@title Record

import noisereduce as nr
import librosa
import numpy as np

SAMPLE_RATE = 22050
record_or_upload = "Record"
record_seconds =   6#@param {type:"number", min:1, max:10, step:1}

def _record_audio(b):
  clear_output()
  global audio
  audio = record_audio(record_seconds, sample_rate=SAMPLE_RATE)
  display(Audio(audio, rate=SAMPLE_RATE, autoplay=True))

# Please set the value
count = 100

for i in df.index[ :count]:
  print(f'Output {i}/{count - 1}')
  print('''
  Recording will be started in 3 seconds
  ↓Please read below sentence↓
  ''')
  print(df['text'][i])
  time.sleep(3)
  # Check the output directory
  output_dir = '/content/drive/MyDrive/record/output_' + str(i) + '.wav'
  audio = record_audio(record_seconds, sample_rate=SAMPLE_RATE)
  reduced_noise = nr.reduce_noise(y=audio, sr=SAMPLE_RATE) # reduce noise
  reduced_noise_trim, index = librosa.effects.trim(reduced_noise) # trim silent part
  write(output_dir, SAMPLE_RATE, reduced_noise_trim)
  print('file saved')
  time.sleep(2)
  output.clear()
# Out:
# Output 0/99
#
#   Recording will be started in 3 seconds
#   ↓Please read below sentence↓
#
# Would such an act of refusal be useful?
# Starting recording for 6 seconds...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-349d7c2f3cce> in <module>()
#      26   time.sleep(3)
#      27   output_dir = '/content/drive/MyDrive/record/output_' + str(i) + '.wav'
# ---> 28   audio = record_audio(record_seconds, sample_rate=SAMPLE_RATE)
#      29   reduced_noise = nr.reduce_noise(y=audio, sr=SAMPLE_RATE) # reduce noise
#      30   reduced_noise_trim, index = librosa.effects.trim(reduced_noise) # trim silent part
#
# /usr/local/lib/python3.7/dist-packages/dl_colab_notebooks/audio.py in record_audio(seconds, sample_rate, normalize_db)
#      70     print('Starting recording for {} seconds...'.format(seconds))
#      71     display.display(display.Javascript(record_js_code))
# ---> 72     audio_string = output.eval_js('record(%d)' % (seconds * 1000.0))
#      73     print('Finished recording!')
#      74     audio_bytes = base64.b64decode(audio_string.split(',')[1])
#
# /usr/local/lib/python3.7/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result, timeout_sec)
#      38   if ignore_result:
#      39     return
# ---> 40   return _message.read_reply_from_input(request_id, timeout_sec)
#      41
#      42
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#      99     reply = _read_next_input_message()
#     100     if reply == _NOT_READY or not isinstance(reply, dict):
# --> 101       time.sleep(0.025)
#     102       continue
#     103     if (reply.get('type') == 'colab_reply' and
#
# KeyboardInterrupt:

# %% [markdown]
# You can check the .wav files whether recording is successful or not

# %%
display(Audio('/content/drive/MyDrive/record/output_13.wav', rate=SAMPLE_RATE, autoplay=True))
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# After recording, we should make aligned filename-script .txt file

# %%
# Preprocess text

import re
chars_to_ignore_regex = '[\,\?\.\!\-\;\:\"]'

for i in df.index:
    df['text'][i] = re.sub(chars_to_ignore_regex, '', df['text'][i]).lower() + "."

# %%
# Get a list of file_names|script
texts = []
for i in df.index[ :count]:
    temp = 'wavs/output_'+ str(i) + '.wav' + '|' + df['text'][i]
    texts.append(temp)

# %%
# Save list as list.txt
with open("/content/drive/MyDrive/record/list.txt", "w") as f:
    for item in texts:
        f.write("%s\n" % item)

# %% [markdown]
# Last step, we should change our .wav files to PCM 16 bit files

# %%
import soundfile
import glob

wavs = glob.glob('/content/drive/MyDrive/record/*.wav')
for i in wavs:
    data, samplerate = soundfile.read(i)
    soundfile.write(i, data, samplerate, subtype='PCM_16')
